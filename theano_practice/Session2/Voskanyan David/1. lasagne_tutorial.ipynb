# %% [markdown]
# # lasagne
# * lasagne is a library for neural network building and training
# * it's a low-level library with almost seamless integration with theano
#
# For a demo we shall solve the same digit recognition problem, but at a different scale
# * images are now 28x28
# * 10 different digits
# * 50k samples

# %%
import numpy as np
import theano
import theano.tensor as T
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from mnist import load_dataset
X_train,y_train,X_val,y_val,X_test,y_test = load_dataset()

print(X_train.shape,y_train.shape)
# Out:
# (50000, 1, 28, 28) (50000,)

# %%
plt.imshow(X_train[0, 0])

# %%
input_X = T.tensor4("X")

#input dimention (None means "Arbitrary" and only works at  the first axes [samples])
input_shape = [None,1,28,28]

target_y = T.vector("target Y integer",dtype='int32')

# %% [markdown]
# Defining network architecture

# %%
import lasagne
from lasagne.layers import *

#Input layer (auxilary)
l1 = InputLayer(shape = input_shape,input_var=input_X)

#fully connected layer, that takes input layer and applies 50 neurons to it.
# nonlinearity here is sigmoid as in logistic regression
# you can give a name to each layer (optional)
l2 = DenseLayer(l1,num_units=512,nonlinearity = lasagne.nonlinearities.linear)

l3 = DropoutLayer(l2, p=0.5)

l5 = DenseLayer(l3,num_units=256,nonlinearity = lasagne.nonlinearities.rectify)


l6 = DenseLayer(l5,num_units=128,nonlinearity = lasagne.nonlinearities.linear)


#fully connected output layer that takes dense_1 as input and has 10 neurons (1 for each digit)
#We use softmax nonlinearity to make probabilities add up to 1
l_out = DenseLayer(l6,num_units = 10,nonlinearity=lasagne.nonlinearities.softmax)

# %%
#network prediction (theano-transformation)
y_predicted = lasagne.layers.get_output(l_out)

# %%
#all network weights (shared variables)
all_weights = lasagne.layers.get_all_params(l_out)
print(all_weights)
# Out:
# [W, b, W, b, W, b, W, b]

# %% [markdown]
# ### Than you could simply
# * define loss function manually
# * compute error gradient over all weights
# * define updates
# * But that's a whole lot of work and life's short
#   * not to mention life's too short to wait for SGD to converge
#
# Instead, we shall use Lasagne builtins

# %%
#Mean categorical crossentropy as a loss function - similar to logistic loss but for multiclass targets
loss = lasagne.objectives.categorical_crossentropy(y_predicted,target_y).mean()

#prediction accuracy
accuracy = lasagne.objectives.categorical_accuracy(y_predicted,target_y).mean()

#This function computes gradient AND composes weight updates just like you did earlier
updates_sgd = lasagne.updates.sgd(loss, all_weights,learning_rate=0.01)

# %%
#function that computes loss and updates weights
train_fun = theano.function([input_X,target_y],[loss,accuracy],updates= updates_sgd)

#function that just computes accuracy
accuracy_fun = theano.function([input_X,target_y],accuracy)

# %% [markdown]
# ### That's all, now let's train it!
# * We got a lot of data, so it's recommended that you use SGD
# * So let's implement a function that splits the training sample into minibatches

# %%
# An auxilary function that returns mini-batches for neural network training

#Parameters
# inputs - a tensor of images with shape (many, 1, 28, 28), e.g. X_train
# outputs - a vector of answers for corresponding images e.g. Y_train
#batch_size - a single number - the intended size of each batches

def iterate_minibatches(inputs, targets, batchsize):
    assert len(inputs) == len(targets)
    indices = np.arange(len(inputs))
    np.random.shuffle(indices)
    for start_idx in range(0, len(inputs) - batchsize + 1, batchsize):
        excerpt = indices[start_idx:start_idx + batchsize]
        yield inputs[excerpt], targets[excerpt]

# %% [markdown]
# # Training loop

# %%
import time

num_epochs = 100 #amount of passes through the data

batch_size = 100 #number of samples processed at each function call

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    train_err = 0
    train_acc = 0
    train_batches = 0
    start_time = time.time()
    for batch in iterate_minibatches(X_train, y_train,batch_size):
        inputs, targets = batch
        train_err_batch, train_acc_batch= train_fun(inputs, targets)
        train_err += train_err_batch
        train_acc += train_acc_batch
        train_batches += 1

    # And a full pass over the validation data:
    val_acc = 0
    val_batches = 0
    for batch in iterate_minibatches(X_val, y_val, batch_size):
        inputs, targets = batch
        val_acc += accuracy_fun(inputs, targets)
        val_batches += 1

    
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))

    print("  training loss (in-iteration):\t\t{:.6f}".format(train_err / train_batches))
    print("  train accuracy:\t\t{:.2f} %".format(
        train_acc / train_batches * 100))
    print("  validation accuracy:\t\t{:.2f} %".format(
        val_acc / val_batches * 100))
# Out:
# Epoch 1 of 100 took 7.310s
#   training loss (in-iteration):		0.240103
#   train accuracy:		92.94 %
#   validation accuracy:		93.59 %
# Epoch 2 of 100 took 8.073s
#   training loss (in-iteration):		0.228426
#   train accuracy:		93.34 %
#   validation accuracy:		93.98 %
# Epoch 3 of 100 took 8.616s
#   training loss (in-iteration):		0.218858
#   train accuracy:		93.53 %
#   validation accuracy:		94.26 %
# Epoch 4 of 100 took 14.689s
#   training loss (in-iteration):		0.209272
#   train accuracy:		93.82 %
#   validation accuracy:		94.64 %
# Epoch 5 of 100 took 16.208s
#   training loss (in-iteration):		0.200451
#   train accuracy:		94.01 %
#   validation accuracy:		94.52 %
# Epoch 6 of 100 took 15.695s
#   training loss (in-iteration):		0.191417
#   train accuracy:		94.41 %
#   validation accuracy:		94.86 %
# Epoch 7 of 100 took 14.552s
#   training loss (in-iteration):		0.184707
#   train accuracy:		94.58 %
#   validation accuracy:		94.81 %
# Epoch 8 of 100 took 15.211s
#   training loss (in-iteration):		0.178191
#   train accuracy:		94.70 %
#   validation accuracy:		95.29 %
# Epoch 9 of 100 took 17.290s
#   training loss (in-iteration):		0.172581
#   train accuracy:		94.78 %
#   validation accuracy:		95.48 %
# Epoch 10 of 100 took 19.417s
#   training loss (in-iteration):		0.167270
#   train accuracy:		94.95 %
#   validation accuracy:		95.12 %
# Epoch 11 of 100 took 14.377s
#   training loss (in-iteration):		0.159698
#   train accuracy:		95.25 %
#   validation accuracy:		95.61 %
# Epoch 12 of 100 took 15.325s
#   training loss (in-iteration):		0.155888
#   train accuracy:		95.44 %
#   validation accuracy:		95.51 %
# Epoch 13 of 100 took 17.554s
#   training loss (in-iteration):		0.153902
#   train accuracy:		95.45 %
#   validation accuracy:		95.36 %
# Epoch 14 of 100 took 14.951s
#   training loss (in-iteration):		0.148442
#   train accuracy:		95.57 %
#   validation accuracy:		95.28 %
# Epoch 15 of 100 took 14.087s
#   training loss (in-iteration):		0.142992
#   train accuracy:		95.76 %
#   validation accuracy:		95.95 %
# Epoch 16 of 100 took 15.614s
#   training loss (in-iteration):		0.140611
#   train accuracy:		95.82 %
#   validation accuracy:		95.91 %
# Epoch 17 of 100 took 18.833s
#   training loss (in-iteration):		0.136806
#   train accuracy:		95.96 %
#   validation accuracy:		95.85 %
# Epoch 18 of 100 took 18.503s
#   training loss (in-iteration):		0.133249
#   train accuracy:		96.01 %
#   validation accuracy:		96.15 %
# Epoch 19 of 100 took 14.013s
#   training loss (in-iteration):		0.131088
#   train accuracy:		96.11 %
#   validation accuracy:		96.20 %
# Epoch 20 of 100 took 16.642s
#   training loss (in-iteration):		0.126519
#   train accuracy:		96.16 %
#   validation accuracy:		96.04 %
# Epoch 21 of 100 took 13.398s
#   training loss (in-iteration):		0.124865
#   train accuracy:		96.24 %
#   validation accuracy:		96.14 %
# Epoch 22 of 100 took 16.226s
#   training loss (in-iteration):		0.120949
#   train accuracy:		96.32 %
#   validation accuracy:		96.21 %
# Epoch 23 of 100 took 14.815s
#   training loss (in-iteration):		0.118667
#   train accuracy:		96.43 %
#   validation accuracy:		96.30 %
# Epoch 24 of 100 took 19.663s
#   training loss (in-iteration):		0.116542
#   train accuracy:		96.43 %
#   validation accuracy:		96.37 %
# Epoch 25 of 100 took 16.854s
#   training loss (in-iteration):		0.113262
#   train accuracy:		96.54 %
#   validation accuracy:		96.34 %
# Epoch 26 of 100 took 15.722s
#   training loss (in-iteration):		0.112169
#   train accuracy:		96.60 %
#   validation accuracy:		96.30 %
# Epoch 27 of 100 took 15.718s
#   training loss (in-iteration):		0.109969
#   train accuracy:		96.69 %
#   validation accuracy:		96.46 %
# Epoch 28 of 100 took 15.301s
#   training loss (in-iteration):		0.108206
#   train accuracy:		96.73 %
#   validation accuracy:		96.60 %
# Epoch 29 of 100 took 16.387s
#   training loss (in-iteration):		0.105177
#   train accuracy:		96.84 %
#   validation accuracy:		96.43 %
# Epoch 30 of 100 took 12.643s
#   training loss (in-iteration):		0.101977
#   train accuracy:		96.85 %
#   validation accuracy:		96.46 %
# Epoch 31 of 100 took 15.624s
#   training loss (in-iteration):		0.101599
#   train accuracy:		96.94 %
#   validation accuracy:		96.71 %
# Epoch 32 of 100 took 20.410s
#   training loss (in-iteration):		0.098933
#   train accuracy:		97.02 %
#   validation accuracy:		96.53 %
# Epoch 33 of 100 took 14.524s
#   training loss (in-iteration):		0.097941
#   train accuracy:		97.07 %
#   validation accuracy:		96.78 %
# Epoch 34 of 100 took 13.152s
#   training loss (in-iteration):		0.095701
#   train accuracy:		97.14 %
#   validation accuracy:		96.63 %
# Epoch 35 of 100 took 14.709s
#   training loss (in-iteration):		0.095807
#   train accuracy:		97.06 %
#   validation accuracy:		96.69 %
# Epoch 36 of 100 took 17.868s
#   training loss (in-iteration):		0.093844
#   train accuracy:		97.12 %
#   validation accuracy:		96.47 %
# Epoch 37 of 100 took 16.292s
#   training loss (in-iteration):		0.091803
#   train accuracy:		97.22 %
#   validation accuracy:		96.82 %
# Epoch 38 of 100 took 18.414s
#   training loss (in-iteration):		0.089629
#   train accuracy:		97.31 %
#   validation accuracy:		96.79 %
# Epoch 39 of 100 took 16.031s
#   training loss (in-iteration):		0.088217
#   train accuracy:		97.31 %
#   validation accuracy:		96.82 %
# Epoch 40 of 100 took 15.361s
#   training loss (in-iteration):		0.085832
#   train accuracy:		97.37 %
#   validation accuracy:		96.93 %
# Epoch 41 of 100 took 16.428s
#   training loss (in-iteration):		0.085032
#   train accuracy:		97.33 %
#   validation accuracy:		96.94 %
# Epoch 42 of 100 took 20.011s
#   training loss (in-iteration):		0.084160
#   train accuracy:		97.38 %
#   validation accuracy:		96.82 %
# Epoch 43 of 100 took 18.732s
#   training loss (in-iteration):		0.083862
#   train accuracy:		97.42 %
#   validation accuracy:		96.86 %
# Epoch 44 of 100 took 15.300s
#   training loss (in-iteration):		0.082333
#   train accuracy:		97.48 %
#   validation accuracy:		96.85 %
# Epoch 45 of 100 took 14.553s
#   training loss (in-iteration):		0.080957
#   train accuracy:		97.55 %
#   validation accuracy:		96.88 %
# Epoch 46 of 100 took 16.999s
#   training loss (in-iteration):		0.080423
#   train accuracy:		97.55 %
#   validation accuracy:		96.97 %
# Epoch 47 of 100 took 16.837s
#   training loss (in-iteration):		0.076647
#   train accuracy:		97.64 %
#   validation accuracy:		96.68 %
# Epoch 48 of 100 took 17.669s
#   training loss (in-iteration):		0.077273
#   train accuracy:		97.61 %
#   validation accuracy:		96.99 %
# Epoch 49 of 100 took 14.329s
#   training loss (in-iteration):		0.075954
#   train accuracy:		97.67 %
#   validation accuracy:		96.91 %
# Epoch 50 of 100 took 16.652s
#   training loss (in-iteration):		0.075701
#   train accuracy:		97.64 %
#   validation accuracy:		97.09 %
# Epoch 51 of 100 took 18.337s
#   training loss (in-iteration):		0.073391
#   train accuracy:		97.70 %
#   validation accuracy:		97.09 %
# Epoch 52 of 100 took 13.648s
#   training loss (in-iteration):		0.072392
#   train accuracy:		97.81 %
#   validation accuracy:		96.95 %
# Epoch 53 of 100 took 18.682s
#   training loss (in-iteration):		0.073392
#   train accuracy:		97.74 %
#   validation accuracy:		97.01 %
# Epoch 54 of 100 took 16.490s
#   training loss (in-iteration):		0.071626
#   train accuracy:		97.76 %
#   validation accuracy:		97.19 %
# Epoch 55 of 100 took 15.309s
#   training loss (in-iteration):		0.070942
#   train accuracy:		97.80 %
#   validation accuracy:		97.08 %
# Epoch 56 of 100 took 16.012s
#   training loss (in-iteration):		0.068324
#   train accuracy:		97.93 %
#   validation accuracy:		97.01 %
# Epoch 57 of 100 took 16.108s
#   training loss (in-iteration):		0.069832
#   train accuracy:		97.84 %
#   validation accuracy:		97.14 %
# Epoch 58 of 100 took 19.526s
#   training loss (in-iteration):		0.069108
#   train accuracy:		97.89 %
#   validation accuracy:		97.02 %
# Epoch 59 of 100 took 14.962s
#   training loss (in-iteration):		0.068365
#   train accuracy:		97.87 %
#   validation accuracy:		97.04 %
# Epoch 60 of 100 took 14.688s
#   training loss (in-iteration):		0.066471
#   train accuracy:		97.91 %
#   validation accuracy:		97.09 %
# Epoch 61 of 100 took 16.239s
#   training loss (in-iteration):		0.066273
#   train accuracy:		97.91 %
#   validation accuracy:		97.27 %
# Epoch 62 of 100 took 12.970s
#   training loss (in-iteration):		0.065129
#   train accuracy:		97.93 %
#   validation accuracy:		97.01 %
# Epoch 63 of 100 took 13.526s
#   training loss (in-iteration):		0.064427
#   train accuracy:		97.95 %
#   validation accuracy:		97.18 %
# Epoch 64 of 100 took 17.720s
#   training loss (in-iteration):		0.063810
#   train accuracy:		98.04 %
#   validation accuracy:		97.27 %
# Epoch 65 of 100 took 16.547s
#   training loss (in-iteration):		0.062619
#   train accuracy:		98.08 %
#   validation accuracy:		97.09 %
# Epoch 66 of 100 took 16.119s
#   training loss (in-iteration):		0.061646
#   train accuracy:		98.04 %
#   validation accuracy:		97.05 %
# Epoch 67 of 100 took 20.025s
#   training loss (in-iteration):		0.061807
#   train accuracy:		98.08 %
#   validation accuracy:		97.04 %
# Epoch 68 of 100 took 16.655s
#   training loss (in-iteration):		0.060270
#   train accuracy:		98.15 %
#   validation accuracy:		97.09 %
# Epoch 69 of 100 took 15.394s
#   training loss (in-iteration):		0.059763
#   train accuracy:		98.09 %
#   validation accuracy:		97.11 %
# Epoch 70 of 100 took 16.548s
#   training loss (in-iteration):		0.058193
#   train accuracy:		98.15 %
#   validation accuracy:		97.05 %
# Epoch 71 of 100 took 15.785s
#   training loss (in-iteration):		0.057989
#   train accuracy:		98.17 %
#   validation accuracy:		96.95 %
# Epoch 72 of 100 took 16.884s
#   training loss (in-iteration):		0.057817
#   train accuracy:		98.17 %
#   validation accuracy:		97.44 %
# Epoch 73 of 100 took 15.398s
#   training loss (in-iteration):		0.057544
#   train accuracy:		98.12 %
#   validation accuracy:		97.27 %
# Epoch 74 of 100 took 15.100s
#   training loss (in-iteration):		0.056484
#   train accuracy:		98.29 %
#   validation accuracy:		97.17 %
# Epoch 75 of 100 took 15.881s
#   training loss (in-iteration):		0.056551
#   train accuracy:		98.22 %
#   validation accuracy:		96.97 %
# Epoch 76 of 100 took 13.326s
#   training loss (in-iteration):		0.055030
#   train accuracy:		98.26 %
#   validation accuracy:		97.26 %
# Epoch 77 of 100 took 16.748s
#   training loss (in-iteration):		0.056165
#   train accuracy:		98.21 %
#   validation accuracy:		97.24 %
# Epoch 78 of 100 took 20.886s
#   training loss (in-iteration):		0.055494
#   train accuracy:		98.26 %
#   validation accuracy:		97.33 %
# Epoch 79 of 100 took 14.860s
#   training loss (in-iteration):		0.053479
#   train accuracy:		98.32 %
#   validation accuracy:		97.16 %
# Epoch 80 of 100 took 11.480s
#   training loss (in-iteration):		0.053840
#   train accuracy:		98.25 %
#   validation accuracy:		97.24 %
# Epoch 81 of 100 took 8.799s
#   training loss (in-iteration):		0.052102
#   train accuracy:		98.36 %
#   validation accuracy:		97.31 %
# Epoch 82 of 100 took 9.058s
#   training loss (in-iteration):		0.053173
#   train accuracy:		98.30 %
#   validation accuracy:		97.25 %
# Epoch 83 of 100 took 8.209s
#   training loss (in-iteration):		0.052442
#   train accuracy:		98.36 %
#   validation accuracy:		97.22 %
# Epoch 84 of 100 took 10.757s
#   training loss (in-iteration):		0.049878
#   train accuracy:		98.43 %
#   validation accuracy:		97.23 %
# Epoch 85 of 100 took 9.928s
#   training loss (in-iteration):		0.050596
#   train accuracy:		98.40 %
#   validation accuracy:		97.28 %
# Epoch 86 of 100 took 7.693s
#   training loss (in-iteration):		0.051648
#   train accuracy:		98.39 %
#   validation accuracy:		97.12 %
# Epoch 87 of 100 took 8.782s
#   training loss (in-iteration):		0.050483
#   train accuracy:		98.46 %
#   validation accuracy:		97.27 %
# Epoch 88 of 100 took 7.988s
#   training loss (in-iteration):		0.051342
#   train accuracy:		98.34 %
#   validation accuracy:		97.46 %
# Epoch 89 of 100 took 6.892s
#   training loss (in-iteration):		0.049013
#   train accuracy:		98.43 %
#   validation accuracy:		97.33 %
# Epoch 90 of 100 took 7.656s
#   training loss (in-iteration):		0.049616
#   train accuracy:		98.44 %
#   validation accuracy:		97.31 %
# Epoch 91 of 100 took 8.287s
#   training loss (in-iteration):		0.049025
#   train accuracy:		98.40 %
#   validation accuracy:		97.32 %
# Epoch 92 of 100 took 7.448s
#   training loss (in-iteration):		0.048248
#   train accuracy:		98.43 %
#   validation accuracy:		97.10 %
# Epoch 93 of 100 took 7.731s
#   training loss (in-iteration):		0.047661
#   train accuracy:		98.43 %
#   validation accuracy:		97.50 %
# Epoch 94 of 100 took 8.944s
#   training loss (in-iteration):		0.046906
#   train accuracy:		98.49 %
#   validation accuracy:		97.28 %
# Epoch 95 of 100 took 9.423s
#   training loss (in-iteration):		0.046472
#   train accuracy:		98.47 %
#   validation accuracy:		97.28 %
# Epoch 96 of 100 took 12.276s
#   training loss (in-iteration):		0.045592
#   train accuracy:		98.54 %
#   validation accuracy:		97.28 %
# Epoch 97 of 100 took 7.898s
#   training loss (in-iteration):		0.046327
#   train accuracy:		98.54 %
#   validation accuracy:		97.32 %
# Epoch 98 of 100 took 8.052s
#   training loss (in-iteration):		0.044339
#   train accuracy:		98.58 %
#   validation accuracy:		97.47 %
# Epoch 99 of 100 took 7.495s
#   training loss (in-iteration):		0.043964
#   train accuracy:		98.64 %
#   validation accuracy:		97.58 %
# Epoch 100 of 100 took 9.464s
#   training loss (in-iteration):		0.043291
#   train accuracy:		98.64 %
#   validation accuracy:		97.59 %

# %%
test_acc = 0
test_batches = 0
for batch in iterate_minibatches(X_test, y_test, 500):
    inputs, targets = batch
    acc = accuracy_fun(inputs, targets)
    test_acc += acc
    test_batches += 1
print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_acc / test_batches * 100))

if test_acc / test_batches * 100 > 99:
    print ("Achievement unlocked: 80lvl Warlock!")
else:
    print ("We need more magic!")
# Out:
# Final results:
#   test accuracy:		97.46 %
# We need more magic!

# %% [markdown]
# # Now improve it!
#
# * Moar layers!
# * Moar units!
# * Different nonlinearities!
